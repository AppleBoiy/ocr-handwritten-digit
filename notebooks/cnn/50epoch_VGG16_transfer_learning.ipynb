# %% [markdown]
# <a href="https://colab.research.google.com/github/AppleBoiy/ocr-handwritten-digit/blob/main/notebooks/cnn/50epoch_VGG16_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handwritten Digit Recognition with CNN
#  Use Transfer Learning with a Pretrained Model
#
#
# 	•	VGG16: VGG16(weights='imagenet', include_top=False)
# 	•	ResNet50: ResNet50(weights='imagenet', include_top=False)
# 	•	MobileNet: MobileNet(weights='imagenet', include_top=False)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# ## Step 2: Load and Preprocess the Data

# %%
import numpy as np
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# ### Original Grayscale Images

# %%
# Select a few samples to visualize
samples_to_visualize = 5
plt.figure(figsize=(15, 3))
for i in range(samples_to_visualize):
    plt.subplot(1, samples_to_visualize, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title('Original (Grayscale)')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Convert Grayscale to RGB (Repeat Channels)

# %%
x_train_rgb = np.repeat(x_train[..., np.newaxis], 3, -1)  # Shape: (60000, 28, 28, 3)
x_test_rgb = np.repeat(x_test[..., np.newaxis], 3, -1)    # Shape: (10000, 28, 28, 3)

plt.figure(figsize=(15, 3))
for i in range(samples_to_visualize):
    plt.subplot(1, samples_to_visualize, i + 1)
    plt.imshow(x_train_rgb[i])
    plt.title('Grayscale to RGB')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Resize to 32x32 (for VGG16)

# %%
x_train_rgb_resized = tf.image.resize(x_train_rgb, (32, 32))
x_test_rgb_resized = tf.image.resize(x_test_rgb, (32, 32))

plt.figure(figsize=(15, 3))
for i in range(samples_to_visualize):
    plt.subplot(1, samples_to_visualize, i + 1)
    plt.imshow(x_train_rgb_resized[i].numpy().astype('uint8'))  # Convert tensor to uint8 for visualization
    plt.title('Resized to 32x32')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalization (Pixel Values in Range [0, 1])

# %%
x_train_rgb_resized_normalized = x_train_rgb_resized / 255.0
x_test_rgb_resized_normalized = x_test_rgb_resized / 255.0

plt.figure(figsize=(15, 3))
for i in range(samples_to_visualize):
    plt.subplot(1, samples_to_visualize, i + 1)
    plt.imshow(x_train_rgb_resized_normalized[i].numpy())
    plt.title('Normalized (0-1)')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Convert class vectors to binary class matrices (one-hot encoding)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Check the shape of training and test data
print(f"Shape of x_train_rgb_resized_normalized: {x_train_rgb_resized_normalized.shape}")
print(f"Shape of x_test_rgb_resized_normalized: {x_test_rgb_resized_normalized.shape}")
# Out:
# Shape of x_train_rgb_resized_normalized: (60000, 32, 32, 3)
# Shape of x_test_rgb_resized_normalized: (10000, 32, 32, 3)

# %% [markdown]
# ## Step 3: Data Augmentation

# %%
x_train_rgb_resized_normalized = x_train_rgb_resized_normalized.numpy()  # Convert to NumPy array
x_test_rgb_resized_normalized = x_test_rgb_resized_normalized.numpy()  # Convert to NumPy array

# %%
x_train_rgb, x_val_rgb, y_train, y_val = train_test_split(
    x_train_rgb_resized_normalized, y_train, test_size=0.2, random_state=42
)

# %%
print(f"Shape of x_train_rgb: {x_train_rgb.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of x_val_rgb: {x_val_rgb.shape}")
print(f"Shape of y_val: {y_val.shape}")
# Out:
# Shape of x_train_rgb: (48000, 32, 32, 3)
# Shape of y_train: (48000, 10)
# Shape of x_val_rgb: (12000, 32, 32, 3)
# Shape of y_val: (12000, 10)

# %% [markdown]
# ## Step 4: Build the CNN Model

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 8, 8, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 4, 4, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 2, 2, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 1, 1, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
model = models.Sequential([
    base_model,  # Pretrained base
    layers.Flatten(),  # Flatten the output of the base model
    layers.Dense(256, activation='relu'),  # Fully connected layer
    layers.Dropout(0.5),  # Add dropout for regularization
    layers.Dense(10, activation='softmax')  # Output layer for 10 classes
])

# %% [markdown]
# ## Step 5: Compile the Model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Step 6: Train the Model

# %%
history = model.fit(x_train_rgb, y_train, epochs=50, batch_size=256,
                    validation_data=(x_val_rgb, y_val),
                    verbose=1)
# Out:
# Epoch 1/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - accuracy: 0.2561 - loss: 2.1326 - val_accuracy: 0.7365 - val_loss: 1.2249
# Epoch 2/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6556 - loss: 1.1902 - val_accuracy: 0.8026 - val_loss: 0.8275
# Epoch 3/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.7586 - loss: 0.8533 - val_accuracy: 0.8391 - val_loss: 0.6481
# Epoch 4/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8052 - loss: 0.6936 - val_accuracy: 0.8630 - val_loss: 0.5366
# Epoch 5/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8301 - loss: 0.5948 - val_accuracy: 0.8832 - val_loss: 0.4615
# Epoch 6/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8530 - loss: 0.5179 - val_accuracy: 0.8936 - val_loss: 0.4073
# Epoch 7/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8693 - loss: 0.4621 - val_accuracy: 0.9032 - val_loss: 0.3657
# Epoch 8/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8848 - loss: 0.4148 - val_accuracy: 0.9099 - val_loss: 0.3346
# Epoch 9/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8906 - loss: 0.3840 - val_accuracy: 0.9164 - val_loss: 0.3093
# Epoch 10/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.8990 - loss: 0.3589 - val_accuracy: 0.9217 - val_loss: 0.2874
# Epoch 11/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9024 - loss: 0.3358 - val_accuracy: 0.9268 - val_loss: 0.2697
# Epoch 12/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9079 - loss: 0.3138 - val_accuracy: 0.9299 - val_loss: 0.2553
# Epoch 13/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9148 - loss: 0.2964 - val_accuracy: 0.9328 - val_loss: 0.2420
# Epoch 14/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9187 - loss: 0.2831 - val_accuracy: 0.9367 - val_loss: 0.2303
# Epoch 15/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9193 - loss: 0.2794 - val_accuracy: 0.9383 - val_loss: 0.2202
# Epoch 16/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9239 - loss: 0.2605 - val_accuracy: 0.9407 - val_loss: 0.2113
# Epoch 17/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9279 - loss: 0.2477 - val_accuracy: 0.9423 - val_loss: 0.2037
# Epoch 18/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9274 - loss: 0.2478 - val_accuracy: 0.9448 - val_loss: 0.1964
# Epoch 19/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9333 - loss: 0.2289 - val_accuracy: 0.9450 - val_loss: 0.1903
# Epoch 20/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9311 - loss: 0.2261 - val_accuracy: 0.9464 - val_loss: 0.1852
# Epoch 21/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9356 - loss: 0.2188 - val_accuracy: 0.9473 - val_loss: 0.1789
# Epoch 22/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9369 - loss: 0.2101 - val_accuracy: 0.9503 - val_loss: 0.1734
# Epoch 23/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9380 - loss: 0.2070 - val_accuracy: 0.9495 - val_loss: 0.1703
# Epoch 24/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9397 - loss: 0.2035 - val_accuracy: 0.9501 - val_loss: 0.1654
# Epoch 25/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9437 - loss: 0.1934 - val_accuracy: 0.9532 - val_loss: 0.1619
# Epoch 26/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9436 - loss: 0.1881 - val_accuracy: 0.9522 - val_loss: 0.1580
# Epoch 27/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9417 - loss: 0.1899 - val_accuracy: 0.9535 - val_loss: 0.1551
# Epoch 28/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9456 - loss: 0.1845 - val_accuracy: 0.9542 - val_loss: 0.1507
# Epoch 29/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9481 - loss: 0.1762 - val_accuracy: 0.9552 - val_loss: 0.1490
# Epoch 30/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9468 - loss: 0.1807 - val_accuracy: 0.9562 - val_loss: 0.1454
# Epoch 31/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9472 - loss: 0.1730 - val_accuracy: 0.9562 - val_loss: 0.1432
# Epoch 32/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9498 - loss: 0.1656 - val_accuracy: 0.9572 - val_loss: 0.1401
# Epoch 33/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9502 - loss: 0.1659 - val_accuracy: 0.9572 - val_loss: 0.1378
# Epoch 34/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9510 - loss: 0.1635 - val_accuracy: 0.9586 - val_loss: 0.1351
# Epoch 35/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9517 - loss: 0.1611 - val_accuracy: 0.9585 - val_loss: 0.1343
# Epoch 36/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9530 - loss: 0.1626 - val_accuracy: 0.9601 - val_loss: 0.1315
# Epoch 37/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9528 - loss: 0.1548 - val_accuracy: 0.9603 - val_loss: 0.1298
# Epoch 38/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9550 - loss: 0.1522 - val_accuracy: 0.9605 - val_loss: 0.1281
# Epoch 39/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9555 - loss: 0.1488 - val_accuracy: 0.9613 - val_loss: 0.1257
# Epoch 40/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9566 - loss: 0.1461 - val_accuracy: 0.9610 - val_loss: 0.1245
# Epoch 41/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9564 - loss: 0.1450 - val_accuracy: 0.9617 - val_loss: 0.1237
# Epoch 42/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9561 - loss: 0.1449 - val_accuracy: 0.9632 - val_loss: 0.1215
# Epoch 43/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9556 - loss: 0.1447 - val_accuracy: 0.9631 - val_loss: 0.1194
# Epoch 44/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9582 - loss: 0.1407 - val_accuracy: 0.9638 - val_loss: 0.1187
# Epoch 45/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9591 - loss: 0.1353 - val_accuracy: 0.9628 - val_loss: 0.1180
# Epoch 46/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.9603 - loss: 0.1340 - val_accuracy: 0.9640 - val_loss: 0.1153
# Epoch 47/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9588 - loss: 0.1337 - val_accuracy: 0.9642 - val_loss: 0.1152
# Epoch 48/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9598 - loss: 0.1355 - val_accuracy: 0.9636 - val_loss: 0.1148
# Epoch 49/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9597 - loss: 0.1317 - val_accuracy: 0.9650 - val_loss: 0.1120
# Epoch 50/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9599 - loss: 0.1313 - val_accuracy: 0.9648 - val_loss: 0.1117

# %%
model.save('mnist_vgg16_transfer_learning.keras')

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Visualize training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 7: Evaluate the Model

# %%
x_test_rgb_resized = tf.image.resize(x_test_rgb, (32, 32)).numpy()  # Resize to (32, 32)
x_test_rgb_resized_normalized = x_test_rgb_resized / 255.0  # Normalize the pixel values

predictions = model.predict(x_test_rgb_resized_normalized)

# Choose an index to display
index = 0

# Get the image, true label, and predicted label
test_image = x_test_rgb_resized_normalized[index]
true_label = y_test[index].argmax()
predicted_label = predictions[index].argmax()

plt.figure(figsize=(6, 6))
plt.imshow(test_image)
plt.title(f'Predicted: {predicted_label}, Expected: {true_label}')
plt.axis('off')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %% [markdown]
# ## Step 8: Visualize Predictions

# %%
# Visualize some predictions
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test_rgb_resized_normalized[i])
    plt.title(f'Predicted: {predictions[i].argmax()}, True: {y_test[i].argmax()}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 9: Report Statistics

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Convert predictions and true labels from one-hot encoding
y_pred = np.argmax(predictions, axis=1)
y_true = np.argmax(y_test, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Visualize the Confusion Matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Calculate precision, recall, and F1-score
report = classification_report(y_true, y_pred, target_names=[str(i) for i in range(10)])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.95      0.96      0.95      1032
#            3       0.94      0.97      0.96      1010
#            4       0.96      0.98      0.97       982
#            5       0.95      0.93      0.94       892
#            6       0.97      0.98      0.98       958
#            7       0.97      0.94      0.95      1028
#            8       0.97      0.96      0.97       974
#            9       0.97      0.95      0.96      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
