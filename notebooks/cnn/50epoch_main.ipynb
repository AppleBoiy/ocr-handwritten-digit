# %% [markdown]
# <a href="https://colab.research.google.com/github/AppleBoiy/ocr-handwritten-digit/blob/main/notebooks/cnn/50epoch_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Handwritten Digit Recognition with CNN (No Early Stopping)

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Load and Preprocess the Data

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape((60000, 28, 28, 1)).astype('float32') / 255
x_test = x_test.reshape((10000, 28, 28, 1)).astype('float32') / 255

# Convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Visualize some of the training images
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
    plt.title(f'Digit: {y_train[i].argmax()}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 3: Data Augmentation

# %%
data_augmentation = models.Sequential([
    layers.RandomRotation(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomZoom(0.1),
])

# Visualize augmented images
plt.figure(figsize=(10, 5))
for i in range(10):
    augmented_image = data_augmentation(tf.expand_dims(x_train[i], 0))
    plt.subplot(2, 5, i + 1)
    plt.imshow(augmented_image[0].numpy().reshape(28, 28), cmap='gray')
    plt.title('Augmented Image')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Build the CNN Model

# %%
model = models.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Step 5: Compile the Model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 3, 3, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 370,954 (1.42 MB)
#  Trainable params: 370,954 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 6: Define Callbacks
#
#
# 1.   The ModelCheckpoint will save the best model based on validation loss during training.
#
# 2.   After the training is done, we'll manually save the last model.

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('mnist_cnn_best_epoch50.keras',
                                                       monitor='val_loss',
                                                       save_best_only=True)

# %% [markdown]
# ## Step 7: Train the Model

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=256,
                    validation_split=0.2,
                    callbacks=[model_checkpoint],  # Saves only the best model
                    verbose=1)

# After training completes, save the final (last) model
model.save('mnist_cnn_last_epoch50.keras')

# Visualize training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Visualize training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.8025 - loss: 0.6715 - val_accuracy: 0.9780 - val_loss: 0.0813
# Epoch 2/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9785 - loss: 0.0691 - val_accuracy: 0.9861 - val_loss: 0.0488
# Epoch 3/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9877 - loss: 0.0410 - val_accuracy: 0.9855 - val_loss: 0.0495
# Epoch 4/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9909 - loss: 0.0307 - val_accuracy: 0.9885 - val_loss: 0.0383
# Epoch 5/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9925 - loss: 0.0237 - val_accuracy: 0.9897 - val_loss: 0.0349
# Epoch 6/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9942 - loss: 0.0181 - val_accuracy: 0.9885 - val_loss: 0.0367
# Epoch 7/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9952 - loss: 0.0157 - val_accuracy: 0.9877 - val_loss: 0.0417
# Epoch 8/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9954 - loss: 0.0133 - val_accuracy: 0.9898 - val_loss: 0.0351
# Epoch 9/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9892 - val_loss: 0.0373
# Epoch 10/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9970 - loss: 0.0091 - val_accuracy: 0.9908 - val_loss: 0.0336
# Epoch 11/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9980 - loss: 0.0065 - val_accuracy: 0.9910 - val_loss: 0.0369
# Epoch 12/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9971 - loss: 0.0070 - val_accuracy: 0.9908 - val_loss: 0.0347
# Epoch 13/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9897 - val_loss: 0.0439
# Epoch 14/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9894 - val_loss: 0.0414
# Epoch 15/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9902 - val_loss: 0.0409
# Epoch 16/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9902 - val_loss: 0.0390
# Epoch 17/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9902 - val_loss: 0.0425
# Epoch 18/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9989 - loss: 0.0030 - val_accuracy: 0.9900 - val_loss: 0.0434
# Epoch 19/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 0.9893 - val_loss: 0.0449
# Epoch 20/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9966 - loss: 0.0104 - val_accuracy: 0.9913 - val_loss: 0.0438
# Epoch 21/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.9926 - val_loss: 0.0398
# Epoch 22/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9910 - val_loss: 0.0427
# Epoch 23/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9921 - val_loss: 0.0366
# Epoch 24/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9919 - val_loss: 0.0386
# Epoch 25/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9998 - loss: 7.5458e-04 - val_accuracy: 0.9921 - val_loss: 0.0438
# Epoch 26/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9908 - val_loss: 0.0403
# Epoch 27/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9922 - val_loss: 0.0382
# Epoch 28/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9991 - loss: 0.0022 - val_accuracy: 0.9908 - val_loss: 0.0459
# Epoch 29/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9988 - loss: 0.0035 - val_accuracy: 0.9922 - val_loss: 0.0390
# Epoch 30/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9912 - val_loss: 0.0417
# Epoch 31/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9913 - val_loss: 0.0404
# Epoch 32/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9930 - val_loss: 0.0360
# Epoch 33/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9906 - val_loss: 0.0506
# Epoch 34/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.9917 - val_loss: 0.0412
# Epoch 35/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9916 - val_loss: 0.0486
# Epoch 36/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9997 - loss: 8.7177e-04 - val_accuracy: 0.9897 - val_loss: 0.0572
# Epoch 37/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9911 - val_loss: 0.0553
# Epoch 38/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9986 - loss: 0.0048 - val_accuracy: 0.9916 - val_loss: 0.0488
# Epoch 39/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9933 - val_loss: 0.0379
# Epoch 40/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9923 - val_loss: 0.0433
# Epoch 41/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9908 - val_loss: 0.0493
# Epoch 42/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9917 - val_loss: 0.0459
# Epoch 43/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9998 - loss: 5.3888e-04 - val_accuracy: 0.9927 - val_loss: 0.0459
# Epoch 44/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9999 - loss: 3.8016e-04 - val_accuracy: 0.9915 - val_loss: 0.0510
# Epoch 45/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9918 - val_loss: 0.0433
# Epoch 46/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.9925 - val_loss: 0.0428
# Epoch 47/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9916 - val_loss: 0.0555
# Epoch 48/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9915 - val_loss: 0.0521
# Epoch 49/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.9912 - val_loss: 0.0446
# Epoch 50/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9909 - val_loss: 0.0570

# %% [markdown]
# ## Step 8: Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9880 - loss: 0.0680
# Test accuracy: 0.9912999868392944

# %% [markdown]
# ## Step 9: Visualize Predictions

# %%
predictions = model.predict(x_test)

# Visualize some predictions
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f'Predicted: {predictions[i].argmax()}, True: {y_test[i].argmax()}')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ## Step 10: Report Statistics

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.argmax(predictions, axis=1)
y_true = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Calculate precision, recall, and F1-score
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       980
#            1       0.99      1.00      0.99      1135
#            2       1.00      0.98      0.99      1032
#            3       0.97      1.00      0.99      1010
#            4       0.99      1.00      0.99       982
#            5       0.99      0.98      0.99       892
#            6       1.00      0.99      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       1.00      0.98      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000
